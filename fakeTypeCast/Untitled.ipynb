# %%
import pandas as pd
import difflib
import jellyfish

# %%
#!pip install jellyfish
# Out:
# ...
#     100% |████████████████████████████████| 133kB 273kB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for jellyfish ... done
#   Stored in directory: /home/a_parida/.cache/pip/wheels/9c/6f/33/92bb9a4b4562a60ba6a80cedbab8907e48bc7a8b1f369ea0ae
# Successfully built jellyfish
# ...

# %%
Reputations=pd.read_csv("reputations.csv")
   # Reputations['site'].apply(lambda x: difflib.get_close_matches(x, url)[0])

# %%
Reputations
# Out:
#                                 source  ScaledRepo
# 0                  100percentfedup.com       0.000
# 1                       365usanews.com       0.000
# 2    4threvolutionarywar.wordpress.com       0.000
# 3                   aheadoftheherd.com       0.000
# 4                      americablog.com       0.000
# 5                  americanlookout.com       0.000
# 6             americanpatriotdaily.com       0.000
# 7                  americanthinker.com       0.000
# 8          americasfreedomfighters.com       0.000
# 9                         AmmoLand.com       0.000
# 10           anotherdayintheempire.com       0.000
# 11                         antiwar.com       0.000
# 12              antoniusaquinas.wp.com       0.000
# 13                   bignuggetnews.com       0.000
# 14                    BrotherJohnF.com       0.000
# 15         centerforsecuritypolicy.org       0.000
# 16                    charismanews.com       0.000
# ...

# %%
def get_closest_match(x,list_strings):
    best_match=None
    highest_jw=0
    
    for current_string in list_strings:
        current_score=jellyfish.jaro_winkler(x,current_string)
        
        if current_score >highest_jw :
            highest_jw =current_score
            best_match=current_string
            
    return best_match

# %%
matching=get_closest_match('wsj.com',list(Reputations['source']))

# %%
matching
# Out:
# 'wnd.com'

# %%
Reputations[Reputations['source']==matching]['ScaledRepo'].iloc[0]
# Out:
# 10.0

# %%
score=1

# %%
0.9*Reputations[Reputations['source']==matching]['ScaledRepo'].iloc[0]+0.1*score
# Out:
# 0.1

# %%
loci=Reputations.index[Reputations['source'] == matching].tolist()[0]

# %%
Reputations.loc[loci,'ScaledRepo']=10
